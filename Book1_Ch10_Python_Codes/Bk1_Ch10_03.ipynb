# %% [markdown]
# Chapter 10
# # 用add_subplot() 方法创建一个新的子图对象
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
import numpy as np
import matplotlib.pyplot as plt 
 
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, y)
plt.show()
